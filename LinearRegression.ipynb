# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/canada_per_capita_income.csv",delim_whitespace=True)
df.head()
# print(len(df))
# Out:
#    year          per  capita  income  (US$)
# 0  1970  3399.299037     NaN     NaN    NaN
# 1  1971  3768.297935     NaN     NaN    NaN
# 2  1972  4251.175484     NaN     NaN    NaN
# 3  1973  4804.463248     NaN     NaN    NaN
# 4  1974  5576.514583     NaN     NaN    NaN

# %%
x = df["year"]
X = np.array(x).reshape(-1,1)
y = df["per"]

# %%
X_train,y_train,X_test,y_test = train_test_split(x,y,test_size=0.2)

# %%
print(type(X_train))
# Out:
# <class 'pandas.core.series.Series'>

# %%
plt.scatter(x,y,c="red",marker='+')
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[1980],[1985]])
# Out:
# array([ 8150.09108551, 12292.41646162])
